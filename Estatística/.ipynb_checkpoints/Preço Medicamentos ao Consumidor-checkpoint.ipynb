# %%
import pandas as pd

# %%
df = pd.read_csv('Dados/TA_PRECO_MEDICAMENTO.csv',  sep=';', encoding='latin-1')
df
# Out:
# C:\Users\Matheus\AppData\Local\Temp\ipykernel_11668\3433932552.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Dados/TA_PRECO_MEDICAMENTO.csv',  sep=';', encoding='latin-1')
#                                               SUBSTÂNCIA                CNPJ  \
# 0      SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE...  33.379.884/0001-96
# 1                       DIENOGESTE;VALERATO DE ESTRADIOL  56.990.534/0001-67
# 2                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  45.987.013/0001-34
# 3                 HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL  45.987.013/0001-34
# 4                                           MONTELUCASTE  45.987.013/0001-34
# ...                                                  ...                 ...
# 26305                            CLORIDRATO DE SEVELÂMER  13.078.518/0001-90
# 26306                                    INSULINA HUMANA  13.078.518/0001-90
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26310 entries, 0 to 26309
# Data columns (total 40 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   SUBSTÂNCIA                                             26310 non-null  object
#  1   CNPJ                                                   26310 non-null  object
#  2   LABORATÓRIO                                            26310 non-null  object
#  3   CÓDIGO GGREM                                           26310 non-null  int64
#  4   REGISTRO                                               26310 non-null  object
#  5   EAN 1                                                  26310 non-null  object
#  6   EAN 2                                                  26310 non-null  object
#  7   EAN 3                                                  26310 non-null  object
# ...

# %%
df['TARJA'].value_counts()
# Out:
# Tarja Vermelha(*)                  10278
# Tarja  Vermelha                     7132
# Tarja Vermelha (*)                  3878
# Tarja -(*)                          1571
# Tarja Venda Livre/Sem Tarja (*)     1551
# Tarja Venda Livre                   1299
# Tarja Preta(*)                       379
# Tarja  Preta                         173
# - (*)                                 49
# Name: TARJA, dtype: int64

# %%
df['RESTRIÇÃO HOSPITALAR'].value_counts()
# Out:
# Não    21856
# Sim     4454
# Name: RESTRIÇÃO HOSPITALAR, dtype: int64

# %%
df['CLASSE TERAPÊUTICA'].value_counts()
# Out:
# N3A - ANTIEPILÉPTICOS                                                                 976
# N5A1 - ANTIPSICÓTICOS ATÍPICOS                                                        747
# M1A1 - ANTIRREUMÁTICOS NÃO ESTEROIDAIS PUROS                                          617
# N2B2 - ANALGÉSICOS NÃO NARCÓTICOS E ANTIPIRÉTICOS ISENTOS DE PRESCRIÇÃO               615
# C7A0 - BETABLOQUEADORES PUROS                                                         608
#                                                                                      ...
# J07A9 - Outro componente único especificado                                             1
# C6A - OUTROS PRODUTOS CARDIOVASCULARES                                                  1
# V6D - OUTROS NUTRIENTES                                                                 1
# S1M - TÔNICOS E VITAMINAS OFTALMOLÓGICAS                                                1
# ...

# %%
df['COMERCIALIZAÇÃO 2020'].value_counts()
# Out:
# Sim    13383
# Não    12927
# Name: COMERCIALIZAÇÃO 2020, dtype: int64

# %%
df['CONFAZ 87'].value_counts()
# Out:
# Não    23284
# Sim     3026
# Name: CONFAZ 87, dtype: int64

# %%
df['LABORATÓRIO'].value_counts()
# Out:
# EMS S/A                                                  1476
# ACHÉ LABORATÓRIOS FARMACÊUTICOS S.A                      1122
# PRATI DONADUZZI & CIA LTDA                                883
# LEGRAND PHARMA INDÚSTRIA FARMACÊUTICA LTDA                875
# GERMED FARMACEUTICA LTDA                                  870
#                                                          ...
# LABORATÓRIO REGIUS LTDA.                                    1
# SS WHITE ARTIGOS DENTARIOS LTDA                             1
# LABORATÓRIO WESP LTDA                                       1
# FARMACIA E LABORATORIO HOMEOPATICO ALMEIDA PRADO LTDA       1
# VISA ESTADUAL SP TESTE                                      1
# Name: LABORATÓRIO, Length: 268, dtype: int64

# %%
df['TIPO DE PRODUTO (STATUS DO PRODUTO)'].value_counts()
# Out:
# Genérico                       9307
# Similar                        8991
# Novo                           4156
# Específico                     2210
# Biológico                      1137
# Fitoterápico                    404
# Biológicos                       54
# -(*)                             24
# Produto de Terapia Avançada      23
# 0                                 2
# Biológico Novo                    1
# Radiofármaco                      1
# Name: TIPO DE PRODUTO (STATUS DO PRODUTO), dtype: int64
