# %%
import pandas as pd
## os principais comandos no pandas em Python

# %%
# uma variável (objeto) dicionário em Python
vendas = {
    'data': ['15/10/2022', '16/10/2022'],
    'valor': [500, 300],
    'produto': ['rivotril solução', 'sertralina 50mg'],
    'quantidade': [10, 15], 
}

print(vendas)
# Out:
# {'data': ['15/10/2022', '16/10/2022'], 'valor': [500, 300], 'produto': ['rivotril solução', 'sertralina 50mg'], 'quantidade': [10, 15]}

# %%
# transformando o dicionário vendas em um DataFrame
vendas_df = pd.DataFrame(vendas)

# %%
display(vendas_df)
# Out:
#          data  valor           produto  quantidade
# 0  15/10/2022    500  rivotril solução          10
# 1  16/10/2022    300   sertralina 50mg          15

# %%
# Importando uma base de dados
mental_df = pd.read_csv('./CSV/Mental Illness Survey 1.csv')
display(mental_df)
# Out:
#      Respondent ID  Collector ID              Start Date  \
# 0              NaN           NaN                     NaN
# 1     6.630447e+09   168522804.0  01/15/2018 03:45:16 AM
# 2     6.630410e+09   168522804.0  01/15/2018 03:17:52 AM
# 3     6.630402e+09   168522804.0  01/15/2018 03:10:28 AM
# 4     6.630335e+09   168522804.0  01/15/2018 02:11:16 AM
# ..             ...           ...                     ...
# 330   6.629053e+09   168522804.0  01/14/2018 03:34:38 AM
# 331   6.629052e+09   168522804.0  01/14/2018 03:34:38 AM
# 332   6.629051e+09   168522804.0  01/14/2018 03:27:20 AM
# 333   6.629051e+09   168522804.0  01/14/2018 03:29:31 AM
# 334   6.629048e+09   168522804.0  01/14/2018 03:24:06 AM
#
#                    End Date  IP Address  Email Address  First Name  Last Name  \
# 0                       NaN         NaN            NaN         NaN        NaN
# 1    01/15/2018 03:48:24 AM         NaN            NaN         NaN        NaN
# ...

# %%
vendas_df.describe()
# Out:
#             valor  quantidade
# count    2.000000    2.000000
# mean   400.000000   12.500000
# std    141.421356    3.535534
# min    300.000000   10.000000
# 25%    350.000000   11.250000
# 50%    400.000000   12.500000
# 75%    450.000000   13.750000
# max    500.000000   15.000000

# %%
mental_df.shape
# Out:
# (335, 40)
