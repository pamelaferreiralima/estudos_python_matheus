# %%
### Exercício 3 de Estatística (Tendência Central)

# %%
pesos = [109.62, 109.27, 49.43, 50.41, 89.94, 11.22, 2.47, 34.25, 1.23, 21.57,
        70.05, 17.81, 45.82, 124.59, 102.56, 11.38, 60.83, 7.23, 12.38, 105.66,
        17.47, 61.29, 7.68, 64.69, 102.91, 1.65, 39.95, 82.96, 90.93, 95.09,
        36.50, 12.79, 67.77, 35.77, 73.37, 25.83, 47.20, 86.54, 115.71, 116.76,
        63.55, 43.71, 119.96, 72.72, 92.92, 28.55, 90.21, 22.25, 47.34, 34.09,
        74.66, 90.51, 100.93, 9.81, 73.40, 56.25, 48.11, 75.01, 124.23, 115.01]
print(pesos)
# Out:
# [109.62, 109.27, 49.43, 50.41, 89.94, 11.22, 2.47, 34.25, 1.23, 21.57, 70.05, 17.81, 45.82, 124.59, 102.56, 11.38, 60.83, 7.23, 12.38, 105.66, 17.47, 61.29, 7.68, 64.69, 102.91, 1.65, 39.95, 82.96, 90.93, 95.09, 36.5, 12.79, 67.77, 35.77, 73.37, 25.83, 47.2, 86.54, 115.71, 116.76, 63.55, 43.71, 119.96, 72.72, 92.92, 28.55, 90.21, 22.25, 47.34, 34.09, 74.66, 90.51, 100.93, 9.81, 73.4, 56.25, 48.11, 75.01, 124.23, 115.01]

# %%
pesos.sort() # ordenando a lista em ordem crescente
print(pesos)
# Out:
# [1.23, 1.65, 2.47, 7.23, 7.68, 9.81, 11.22, 11.38, 12.38, 12.79, 17.47, 17.81, 21.57, 22.25, 25.83, 28.55, 34.09, 34.25, 35.77, 36.5, 39.95, 43.71, 45.82, 47.2, 47.34, 48.11, 49.43, 50.41, 56.25, 60.83, 61.29, 63.55, 64.69, 67.77, 70.05, 72.72, 73.37, 73.4, 74.66, 75.01, 82.96, 86.54, 89.94, 90.21, 90.51, 90.93, 92.92, 95.09, 100.93, 102.56, 102.91, 105.66, 109.27, 109.62, 115.01, 115.71, 116.76, 119.96, 124.23, 124.59]

# %%
pesos.mean() # descobrindo a média da lista
# Out:
# Element      60.063333
# Frequency     1.000000
# dtype: float64

# %%
pesos.median() # descobrindo a mediana da lista
# Out:
# Element      61.06
# Frequency     1.00
# dtype: float64

# %%
import pandas as pd

# %%
pesos = pd.Series(pesos).value_counts().sort_index().reset_index().reset_index(drop=True)
pesos.columns = ['Element', 'Frequency']

# %%
display(pesos)
# Out:
#     Element  Frequency
# 0      1.23          1
# 1      1.65          1
# 2      2.47          1
# 3      7.23          1
# 4      7.68          1
# 5      9.81          1
# 6     11.22          1
# 7     11.38          1
# 8     12.38          1
# 9     12.79          1
# 10    17.47          1
# 11    17.81          1
# 12    21.57          1
# 13    22.25          1
# 14    25.83          1
# 15    28.55          1
# 16    34.09          1
# 17    34.25          1
# 18    35.77          1
# 19    36.50          1
# 20    39.95          1
# 21    43.71          1
# 22    45.82          1
# 23    47.20          1
# 24    47.34          1
# 25    48.11          1
# 26    49.43          1
# 27    50.41          1
# 28    56.25          1
# 29    60.83          1
# 30    61.29          1
# 31    63.55          1
# 32    64.69          1
# 33    67.77          1
# 34    70.05          1
# 35    72.72          1
# 36    73.37          1
# 37    73.40          1
# 38    74.66          1
# ...
